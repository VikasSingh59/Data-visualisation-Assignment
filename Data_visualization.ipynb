# %% [markdown]
# <a href="https://colab.research.google.com/github/VikasSingh59/Data-visualisation-Assignment/blob/main/Data_visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline
import seaborn as sns

from numpy.random import randn, randint, uniform, sample

# %%
x= [1,2,3,4,5,6,7,8,9]
y1 = [1,3, 5, 3, 1, 3, 5, 3, 1]
y2 = [2, 4, 6, 4, 2, 4, 6, 4, 2]
plt.plot(x,y1,label="line L")
plt.plot(x,y2,label="line H")
plt.plot()
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.title("line Graph")
plt.legend()
plt.show()

# %%
# Bar Graph
### bar plot


x = [2,8,10]
y = [11,16,9]

x2 =[3,9,11]
y2 =[6,15,7]
plt.bar(x, y, label = "x-y variation")
plt.bar(x2, y2, color = 'g', label = "x2-y2")
plt.title('bar graph')
plt.ylabel('y axis')
plt.xlabel('x axis')
plt.legend()
plt.show()

# %%
x1 =[1, 3, 4, 5, 6, 7, 9]
y1 =[4, 7, 2, 4, 7, 8, 3]

x2 =[2, 4, 6, 8, 10]
y2 =[5, 6, 2, 6, 2]
# colors:

plt.bar(x1, y1, label="Blue Bar", color='b')
plt.bar(x2, y2, label="Green Bar", color='g')
plt.plot()

plt.xlabel("bar number")
plt.ylabel("bar height")
plt.title("bar chart Example")
plt.legend()
plt.show()

# %%
a = np.array([22,87,5,43,1,56,79,55,54,23,11,51,5,10,79,31,27,19,65])
plt.hist(a)
plt.title("Histogram")
plt.show()

# %%
iris = sns.load_dataset('iris')
iris.head(5)

# sepal_length  sepal_width  petal_length  petal_width  species
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
# iris['sepal_length']
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'tips',
#  'titanic']

# %%
iris['species'].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
iris = sns.load_dataset('iris')
iris.tail(5)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
iris['sepal_length'].plot.hist()

# %%
iris.plot.hist()   ### iris.plot(kind = 'hist)

# %%
iris.plot(kind = 'hist')

# %%
iris.plot(kind = 'hist', stacked = False, bins = 20)

# %%
iris.plot(kind = 'hist', stacked = True, bins = 20)

# %%
# df = iris.drop([species])
iris['sepal_width']
# Out:
# 0      3.5
# 1      3.0
# 2      3.2
# 3      3.1
# 4      3.6
#       ...
# 145    3.0
# 146    2.5
# 147    3.0
# 148    3.4
# 149    3.0
# Name: sepal_width, Length: 150, dtype: float64

# %%
iris['sepal_width'].diff()
# Out:
# 0      NaN
# 1     -0.5
# 2      0.2
# 3     -0.1
# 4      0.5
#       ...
# 145   -0.3
# 146   -0.5
# 147    0.5
# 148    0.4
# 149   -0.4
# Name: sepal_width, Length: 150, dtype: float64

# %%
iris['sepal_width'].diff().plot(kind = 'hist', stacked = True, bins = 20)

# %%
df = iris.drop(['species'], axis = 1)
df.diff().head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           NaN          NaN           NaN          NaN
# 1          -0.2         -0.5           0.0          0.0
# 2          -0.2          0.2          -0.1          0.0
# 3          -0.1         -0.1           0.2          0.0
# 4           0.4          0.5          -0.1          0.0

# %%
df.hist(color = '#FF33F4', alpha = 0.3, figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f998b917150>,
# ...
#       dtype=object)

# %% [markdown]
# pie chart

# %%
#data to plot
labels = 'python', 'c++', 'Ruby', 'java'
sizes = [215,130,245,210]
colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue']
explode = (0.1, 0.1, 0.1, 0.1)  
#explode

#plot
plt.pie(sizes,  explode=explode, labels=labels, colors=colors,
autopct= '%1.2f%%', shadow=False)

plt.axis('equal')
plt.show()

# %%
series = pd.serie ([0.2]*5,  index = ['a','b','c','d','e'], name = 'Pie Plot')
series.plot.pie()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-62-1b608c4b1aaa> in <module>()
# ----> 1 series = pd.serie ([0.2]*5,  index = ['a','b','c','d','e'], name = 'Pie Plot')
#       2 series.plot.pie()
#
# /usr/local/lib/python3.7/dist-packages/pandas/__init__.py in __getattr__(name)
#     256             return _SparseArray
#     257
# --> 258         raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     259
#     260
#
# AttributeError: module 'pandas' has no attribute 'serie'

# %%
df.plot.scatter(x ='sepal_length', y ='petal_length')

# %%
df.plot.scatter(x ='sepal_length', y ='petal_length', c ='sepal_width', )

# %% [markdown]
# **assignment day -2 **

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
# %matplotlib inline
from numpy.random import randn,randint,uniform,sample

# %%
df=pd.DataFrame(randn(10,4),columns=['a','b','c','d'])
df
# Out:
#           a         b         c         d
# 0  0.560464  0.495493 -1.531678 -0.361239
# 1 -0.076194  0.612503 -0.592215  1.541584
# 2 -1.374973 -1.051574 -0.665236  0.264025
# 3 -0.220293 -1.645404  0.777089  0.291591
# 4  0.766346 -0.982694 -0.069694  0.761796
# 5 -0.310226  0.720747  1.208496  0.496849
# 6  0.645649 -0.354649  0.554787 -0.637081
# 7 -0.486092  2.116343  1.741796  0.536770
# 8 -0.560140 -0.568470 -0.283982 -0.198250
# 9 -0.714323  1.395877 -1.232050 -0.072835

# %%
df.plot(kind='bar',title='Bar Chart',figsize=(10,10),grid=True,legend = True)
